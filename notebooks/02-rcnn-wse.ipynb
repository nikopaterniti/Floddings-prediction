# %% [markdown]
# ### Functions

# %%
import numpy as np
import pandas as pd
import os
from pathlib import Path
import tqdm
import matplotlib.pyplot as plt
import random
import torch
import torch.nn as nn
import torch.optim as optim
import seaborn as sns
#import wandb

# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, SGD

import keras.layers.advanced_activations as advanced_activations
import keras.activations as activations
import keras.layers as layers
from keras.layers import Dense, concatenate
from keras.callbacks import EarlyStopping

# %%
def shuffle_weights(model, weights=None):
    """Randomly permute the weights in `model`, or the given `weights`.
    This is a fast approximation of re-initializing the weights of a model.
    Assumes weights are distributed independently of the dimensions of the weight tensors
      (i.e., the weights have the same distribution along each dimension).
    :param Model model: Modify the weights of the given model.
    :param list(ndarray) weights: The model's weights will be replaced by a random permutation of these weights.
      If `None`, permute the model's current weights.
    """
    if weights is None:
        weights = model.get_weights()
    weights = [np.random.permutation(w.flat).reshape(w.shape) for w in weights]
    # Faster, but less random: only permutes along the first dimension
    # weights = [np.random.permutation(w) for w in weights]
    model.set_weights(weights)

# %%
import scipy.spatial.distance as distance
def plot_mat_accuracy(input, y_hat, y_true):

  input = input
  y_hat = y_hat
  y_true = y_true

  dist = distance.cosine(y_hat.flatten(), y_true.flatten())

  fig, axs = plt.subplots(1,3)
  fig.suptitle('Accuracy: {}'.format(1 - dist))
  
  axs[0].set_title("Input")
  axs[0].matshow(input)

  axs[1].set_title("Y_hat")
  axs[1].matshow(y_hat)

  axs[2].set_title("Y_true")
  axs[2].matshow(y_true)
  
  for ax in axs:
    ax.set_xticks([])
    ax.set_yticks([])

  plt.show()
      
  return 1 - dist

def get_mat_accuracy(y_hat, y_true):
  dist = distance.cosine(y_hat.flatten(), y_true.flatten())
  return 1 - dist

# %% [markdown]
# ### Data Import

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %cd drive/My\ Drive/SWE
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/My Drive/SWE

# %%
portate = np.load('datasets/numpy/portate.npy')
print(portate.shape)

wses = np.load('datasets/numpy/wses.npy')
print(wses.shape)

btms = np.load('datasets/numpy/btms.npy')
print(btms.shape)
# Out:
# (100, 1, 3, 4)
# (100, 1, 448, 640)
# (100, 1, 448, 640)

# %% [markdown]
# ### CNN

# %% [markdown]
# #### Data preprocessing

# %%
# Tolgo 2* dimensione che incapsula
btms.resize(btms.shape[0], btms.shape[2], btms.shape[3])
wses.resize(wses.shape[0], wses.shape[2], wses.shape[3])

# %%
portate.resize(portate.shape[0], portate.shape[2], portate.shape[3])

# %%
# (time index, portata)
portate = portate[:, :, [0,2]]

# %%
print(portate.shape)
print(btms.shape)
print(wses.shape)
# Out:
# (100, 3, 2)
# (100, 448, 640)
# (100, 448, 640)

# %%
TRAIN_SIZE = int(wses.shape[0] * 0.9)

train_indices = np.unique(random.sample(list(range(portate.shape[0])), TRAIN_SIZE))
test_indices = [i for i in range(wses.shape[0]) if i not in train_indices]

# 2 input, 1 output
x_train_img, y_train = btms[train_indices], wses[train_indices]
x_train_prt = portate[train_indices]

# 2 input, 1 output
x_test_img, y_test = btms[test_indices], wses[test_indices]
x_test_prt = portate[test_indices]

# %%
# Reshape to channel last
x_train_img = x_train_img.reshape(-1, x_train_img.shape[1], x_train_img.shape[2], 1)
x_test_img = x_test_img.reshape(-1, x_test_img.shape[1], x_test_img.shape[2], 1)

y_train = y_train.reshape(-1, y_train.shape[1], y_train.shape[2], 1)

# %% [markdown]
# #### Modeling

# %% [markdown]
# Parametri piú rilevanti:
#
# 1.   Convolution Blocks (val_accuracy alta)
# 2.   Neuroni Densi alla fine (immagine chiara)
# 3.   Kernel Size (smoothing + dettagli)
# 4.   Leaky ReLU Slope (smoothing)

# %%
hyperparameters = dict(
    
    convolution_blocks = 16, # da 8 comincia a migliorare la val_accuracy!!
    dense_blocks = 4,

    res_net = False,
    skips = 2,

    filters = 8,        # X canali in uscita

    kernels = (27, 27), # 3 = minimo odd number valido
                        # 2 = asimmetrico, filtro irregolare
                        # 1 = come se non ci fossero vicini
                        # forse un kernel piú grosso aiuta a stabilizzare l'accuracy
                       
    dense = 1024,
    lstm = 16, 

    epochs = 100,

    lrelu_slope = 0.5,

    optimizer = "adam",  # SGD converge meglio di Adam, ma é molto piú lento
    sgd_momentum = 0.9,

    learning_rate = 1e-3,
    batch_size = 64
)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Dropout, Add
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Reshape
from tensorflow.keras.models import Model

# %%
def feed_forward(config, dim, regress=False):
    
  inputs = Input(shape = dim)

  x = inputs
  x = LSTM(config["lstm"])(inputs)
  x = layers.Flatten()(x)
  x = BatchNormalization()(x)

  #x = Dense(16)(x)
  #x = layers.LeakyReLU(x)
  #x = Dense(32)(x)

  return Model(inputs, x)

# %%
def build_cnn(config, width, height, depth, regress=False):

  inputShape = (height, width, depth)
  chanDim = -1

  inputs = Input(shape = inputShape)

  x = inputs

  x = BatchNormalization(axis=chanDim)(x)

  # 0, 1, 2, 3
  for i in range(config["convolution_blocks"]):

    x = Conv2D(config["filters"], config["kernels"], padding="same")(x)
  
    # Inner connections 2 
    if config["res_net"]:   
      y = Conv2D(config["filters"], config["kernels"], padding="same")(x)
      y = BatchNormalization()(y)

      for j in range(config["skips"] - 1):
        y = Conv2D(config["filters"], config["kernels"], padding="same")(y)
        y = BatchNormalization()(y)

      # Skip connection
      x = Add()([x, y])
    
    x = BatchNormalization(axis=chanDim)(x)

    # Applica N/2 poolings
    if i % 2 == 0:
      x = AveragePooling2D(2)(x)

    #x = layers.LeakyReLU(config["lrelu_slope"])(x)

  # Final dense
  x = Flatten()(x)

  model = Model(inputs, x)

  return model

# %%
def train(config = None):

  #with wandb.init(config = config, project="shallow-water-emulations", entity="diego-calanzone"):
        
    #config = wandb.config

  # Build the network
  mlp = feed_forward(config, (portate.shape[1], portate.shape[2]), regress=False)
  cnn = build_cnn(config, x_train_img.shape[2], x_train_img.shape[1], x_train_img.shape[3])
  combinedInput = concatenate([mlp.output, cnn.output])

  # Dense blocks
  for i in range(config["dense_blocks"]):
    x = Dense(config["dense"])(combinedInput)
    x = BatchNormalization()(x)

  # Final Reshape
  x = Dense(y_train.shape[2] * y_train.shape[1])(x)
  x = layers.LeakyReLU(config["lrelu_slope"])(x)

  x = Reshape((y_train.shape[1], y_train.shape[2], y_train.shape[3]))(x)

  model = Model(inputs=[mlp.input, cnn.input], outputs=x)

  # Compile
  if config["optimizer"] == 'adam':
    opt = Adam(lr=config["learning_rate"])
  else:
    opt = SGD(lr=config["learning_rate"], momentum=config["sgd_momentum"])

  model.compile(loss="mean_squared_error", optimizer=opt, metrics=["accuracy"])
  tf.keras.utils.plot_model(model, to_file="model_plot.png", show_shapes=True)

  # Train
  model.fit(
    x = [x_train_prt, x_train_img], 
    y =  y_train,
    validation_data = ([x_test_prt, x_test_img], y_test),
    epochs = config["epochs"], 
    shuffle = 1,
    batch_size = config["batch_size"],
    verbose = 1,
    #callbacks=[WandbCallback()]
  )

  return model

# %%
model = train(hyperparameters)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 33s 10s/step - loss: 11.9013 - accuracy: 0.7641 - val_loss: 11.6574 - val_accuracy: 0.7672
# Epoch 2/100
# 2/2 [==============================] - 5s 2s/step - loss: 11.6556 - accuracy: 0.7639 - val_loss: 11.6016 - val_accuracy: 0.7672
# Epoch 3/100
# 2/2 [==============================] - 5s 2s/step - loss: 11.4001 - accuracy: 0.7610 - val_loss: 11.5329 - val_accuracy: 0.7672
# Epoch 4/100
# 2/2 [==============================] - 5s 2s/step - loss: 10.9476 - accuracy: 0.7599 - val_loss: 11.4528 - val_accuracy: 0.7672
# Epoch 5/100
# 2/2 [==============================] - 5s 2s/step - loss: 10.6972 - accuracy: 0.7569 - val_loss: 11.3656 - val_accuracy: 0.7672
# Epoch 6/100
# 2/2 [==============================] - 5s 2s/step - loss: 10.4621 - accuracy: 0.7573 - val_loss: 11.2792 - val_accuracy: 0.7672
# Epoch 7/100
# 2/2 [==============================] - 5s 2s/step - loss: 10.3666 - accuracy: 0.7558 - val_loss: 11.2038 - val_accuracy: 0.7336
# Epoch 8/100
# 2/2 [==============================] - 5s 2s/step - loss: 10.3804 - accuracy: 0.7566 - val_loss: 11.1641 - val_accuracy: 0.7272
# Epoch 9/100
# 2/2 [==============================] - 5s 2s/step - loss: 10.4626 - accuracy: 0.7564 - val_loss: 11.1568 - val_accuracy: 0.7266
# Epoch 10/100
# 2/2 [==============================] - 5s 2s/step - loss: 10.4172 - accuracy: 0.7567 - val_loss: 11.1698 - val_accuracy: 0.7269
# Epoch 11/100
# 2/2 [==============================] - 5s 2s/step - loss: 10.3679 - accuracy: 0.7568 - val_loss: 11.1899 - val_accuracy: 0.7276
# Epoch 12/100
# 2/2 [==============================] - 5s 2s/step - loss: 10.3372 - accuracy: 0.7572 - val_loss: 11.2045 - val_accuracy: 0.7287
# Epoch 13/100
# 2/2 [==============================] - 5s 2s/step - loss: 10.2328 - accuracy: 0.7594 - val_loss: 11.2053 - val_accuracy: 0.7298
# Epoch 14/100
# 2/2 [==============================] - 5s 2s/step - loss: 10.2849 - accuracy: 0.7580 - val_loss: 11.1808 - val_accuracy: 0.7300
# Epoch 15/100
# 2/2 [==============================] - 5s 2s/step - loss: 10.2379 - accuracy: 0.7579 - val_loss: 11.1300 - val_accuracy: 0.7292
# Epoch 16/100
# 2/2 [==============================] - 5s 2s/step - loss: 10.2023 - accuracy: 0.7585 - val_loss: 11.0531 - val_accuracy: 0.7279
# Epoch 17/100
# 2/2 [==============================] - 5s 2s/step - loss: 10.1203 - accuracy: 0.7600 - val_loss: 10.9556 - val_accuracy: 0.7269
# Epoch 18/100
# 2/2 [==============================] - 5s 2s/step - loss: 9.9695 - accuracy: 0.7596 - val_loss: 10.8431 - val_accuracy: 0.7259
# Epoch 19/100
# 2/2 [==============================] - 5s 2s/step - loss: 10.0309 - accuracy: 0.7585 - val_loss: 10.7256 - val_accuracy: 0.7243
# Epoch 20/100
# 2/2 [==============================] - 5s 2s/step - loss: 9.9686 - accuracy: 0.7605 - val_loss: 10.6074 - val_accuracy: 0.7234
# Epoch 21/100
# 2/2 [==============================] - 5s 2s/step - loss: 9.9271 - accuracy: 0.7579 - val_loss: 10.4980 - val_accuracy: 0.7221
# Epoch 22/100
# 2/2 [==============================] - 5s 2s/step - loss: 9.8027 - accuracy: 0.7586 - val_loss: 10.3996 - val_accuracy: 0.7216
# Epoch 23/100
# 2/2 [==============================] - 5s 2s/step - loss: 9.7553 - accuracy: 0.7593 - val_loss: 10.3101 - val_accuracy: 0.7212
# Epoch 24/100
# 2/2 [==============================] - 5s 2s/step - loss: 9.6165 - accuracy: 0.7579 - val_loss: 10.2160 - val_accuracy: 0.7210
# Epoch 25/100
# 2/2 [==============================] - 5s 2s/step - loss: 9.5236 - accuracy: 0.7576 - val_loss: 10.1094 - val_accuracy: 0.7204
# Epoch 26/100
# 2/2 [==============================] - 5s 2s/step - loss: 9.2911 - accuracy: 0.7588 - val_loss: 9.9760 - val_accuracy: 0.7200
# Epoch 27/100
# 2/2 [==============================] - 5s 2s/step - loss: 9.2319 - accuracy: 0.7581 - val_loss: 9.8052 - val_accuracy: 0.7196
# Epoch 28/100
# 2/2 [==============================] - 5s 2s/step - loss: 9.1265 - accuracy: 0.7570 - val_loss: 9.5758 - val_accuracy: 0.7192
# Epoch 29/100
# 2/2 [==============================] - 5s 2s/step - loss: 8.8436 - accuracy: 0.7586 - val_loss: 9.2511 - val_accuracy: 0.7183
# Epoch 30/100
# 2/2 [==============================] - 5s 2s/step - loss: 8.6818 - accuracy: 0.7568 - val_loss: 8.8722 - val_accuracy: 0.7176
# Epoch 31/100
# 2/2 [==============================] - 5s 2s/step - loss: 8.3715 - accuracy: 0.7580 - val_loss: 8.4497 - val_accuracy: 0.7171
# Epoch 32/100
# 2/2 [==============================] - 5s 2s/step - loss: 8.0821 - accuracy: 0.7575 - val_loss: 8.0120 - val_accuracy: 0.7169
# Epoch 33/100
# 2/2 [==============================] - 5s 2s/step - loss: 7.7397 - accuracy: 0.7566 - val_loss: 7.5969 - val_accuracy: 0.7168
# Epoch 34/100
# 2/2 [==============================] - 5s 2s/step - loss: 7.2300 - accuracy: 0.7564 - val_loss: 7.1722 - val_accuracy: 0.7167
# Epoch 35/100
# 2/2 [==============================] - 5s 2s/step - loss: 6.8230 - accuracy: 0.7510 - val_loss: 6.6431 - val_accuracy: 0.7166
# Epoch 36/100
# 2/2 [==============================] - 5s 2s/step - loss: 6.3333 - accuracy: 0.7490 - val_loss: 6.0014 - val_accuracy: 0.7161
# Epoch 37/100
# 2/2 [==============================] - 5s 2s/step - loss: 5.8032 - accuracy: 0.7487 - val_loss: 5.3415 - val_accuracy: 0.7160
# Epoch 38/100
# 2/2 [==============================] - 5s 2s/step - loss: 5.2413 - accuracy: 0.7499 - val_loss: 4.7387 - val_accuracy: 0.7160
# Epoch 39/100
# 2/2 [==============================] - 5s 2s/step - loss: 4.7054 - accuracy: 0.7478 - val_loss: 4.1678 - val_accuracy: 0.7159
# Epoch 40/100
# 2/2 [==============================] - 5s 2s/step - loss: 4.0983 - accuracy: 0.7447 - val_loss: 3.6153 - val_accuracy: 0.7156
# Epoch 41/100
# 2/2 [==============================] - 5s 2s/step - loss: 3.5415 - accuracy: 0.7404 - val_loss: 3.0889 - val_accuracy: 0.7155
# Epoch 42/100
# 2/2 [==============================] - 5s 2s/step - loss: 3.0537 - accuracy: 0.7388 - val_loss: 2.6065 - val_accuracy: 0.7155
# Epoch 43/100
# 2/2 [==============================] - 5s 2s/step - loss: 2.5476 - accuracy: 0.7374 - val_loss: 2.1912 - val_accuracy: 0.7155
# Epoch 44/100
# 2/2 [==============================] - 5s 2s/step - loss: 2.1674 - accuracy: 0.7343 - val_loss: 1.8427 - val_accuracy: 0.7155
# Epoch 45/100
# 2/2 [==============================] - 5s 2s/step - loss: 1.7770 - accuracy: 0.7310 - val_loss: 1.5580 - val_accuracy: 0.7154
# Epoch 46/100
# 2/2 [==============================] - 5s 2s/step - loss: 1.4694 - accuracy: 0.7297 - val_loss: 1.3473 - val_accuracy: 0.7154
# Epoch 47/100
# 2/2 [==============================] - 5s 2s/step - loss: 1.2208 - accuracy: 0.7287 - val_loss: 1.1972 - val_accuracy: 0.7155
# Epoch 48/100
# 2/2 [==============================] - 5s 2s/step - loss: 1.0136 - accuracy: 0.7288 - val_loss: 1.1037 - val_accuracy: 0.7156
# Epoch 49/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.8586 - accuracy: 0.7286 - val_loss: 1.0617 - val_accuracy: 0.7159
# Epoch 50/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.7561 - accuracy: 0.7277 - val_loss: 1.0562 - val_accuracy: 0.7159
# Epoch 51/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6967 - accuracy: 0.7282 - val_loss: 1.0785 - val_accuracy: 0.7159
# Epoch 52/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6698 - accuracy: 0.7287 - val_loss: 1.1118 - val_accuracy: 0.7159
# Epoch 53/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6381 - accuracy: 0.7279 - val_loss: 1.1573 - val_accuracy: 0.7159
# Epoch 54/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6806 - accuracy: 0.7286 - val_loss: 1.1976 - val_accuracy: 0.7160
# Epoch 55/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6692 - accuracy: 0.7286 - val_loss: 1.2168 - val_accuracy: 0.7160
# Epoch 56/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6928 - accuracy: 0.7280 - val_loss: 1.2398 - val_accuracy: 0.7160
# Epoch 57/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.7001 - accuracy: 0.7289 - val_loss: 1.2541 - val_accuracy: 0.7160
# Epoch 58/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.7001 - accuracy: 0.7300 - val_loss: 1.2391 - val_accuracy: 0.7160
# Epoch 59/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6568 - accuracy: 0.7291 - val_loss: 1.2179 - val_accuracy: 0.7160
# Epoch 60/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6465 - accuracy: 0.7297 - val_loss: 1.1981 - val_accuracy: 0.7163
# Epoch 61/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6633 - accuracy: 0.7310 - val_loss: 1.1639 - val_accuracy: 0.7165
# Epoch 62/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6566 - accuracy: 0.7309 - val_loss: 1.1291 - val_accuracy: 0.7166
# Epoch 63/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6143 - accuracy: 0.7312 - val_loss: 1.1077 - val_accuracy: 0.7169
# Epoch 64/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6089 - accuracy: 0.7323 - val_loss: 1.0895 - val_accuracy: 0.7170
# Epoch 65/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6465 - accuracy: 0.7334 - val_loss: 1.0675 - val_accuracy: 0.7170
# Epoch 66/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6204 - accuracy: 0.7325 - val_loss: 1.0529 - val_accuracy: 0.7169
# Epoch 67/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6164 - accuracy: 0.7323 - val_loss: 1.0478 - val_accuracy: 0.7169
# Epoch 68/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6101 - accuracy: 0.7330 - val_loss: 1.0411 - val_accuracy: 0.7168
# Epoch 69/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6122 - accuracy: 0.7339 - val_loss: 1.0322 - val_accuracy: 0.7167
# Epoch 70/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6134 - accuracy: 0.7323 - val_loss: 1.0266 - val_accuracy: 0.7167
# Epoch 71/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6245 - accuracy: 0.7322 - val_loss: 1.0243 - val_accuracy: 0.7167
# Epoch 72/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.5959 - accuracy: 0.7319 - val_loss: 1.0224 - val_accuracy: 0.7169
# Epoch 73/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6099 - accuracy: 0.7336 - val_loss: 1.0214 - val_accuracy: 0.7170
# Epoch 74/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6253 - accuracy: 0.7322 - val_loss: 1.0182 - val_accuracy: 0.7171
# Epoch 75/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6031 - accuracy: 0.7319 - val_loss: 1.0176 - val_accuracy: 0.7172
# Epoch 76/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6214 - accuracy: 0.7316 - val_loss: 1.0196 - val_accuracy: 0.7173
# Epoch 77/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6284 - accuracy: 0.7315 - val_loss: 1.0190 - val_accuracy: 0.7173
# Epoch 78/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6208 - accuracy: 0.7314 - val_loss: 1.0200 - val_accuracy: 0.7172
# Epoch 79/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6376 - accuracy: 0.7302 - val_loss: 1.0203 - val_accuracy: 0.7171
# Epoch 80/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6012 - accuracy: 0.7304 - val_loss: 1.0231 - val_accuracy: 0.7170
# Epoch 81/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6114 - accuracy: 0.7308 - val_loss: 1.0253 - val_accuracy: 0.7170
# Epoch 82/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6099 - accuracy: 0.7312 - val_loss: 1.0248 - val_accuracy: 0.7170
# Epoch 83/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6364 - accuracy: 0.7302 - val_loss: 1.0228 - val_accuracy: 0.7170
# Epoch 84/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6316 - accuracy: 0.7308 - val_loss: 1.0215 - val_accuracy: 0.7170
# Epoch 85/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6241 - accuracy: 0.7310 - val_loss: 1.0208 - val_accuracy: 0.7170
# Epoch 86/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6406 - accuracy: 0.7311 - val_loss: 1.0188 - val_accuracy: 0.7171
# Epoch 87/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6182 - accuracy: 0.7311 - val_loss: 1.0170 - val_accuracy: 0.7173
# Epoch 88/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6256 - accuracy: 0.7311 - val_loss: 1.0157 - val_accuracy: 0.7174
# Epoch 89/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6166 - accuracy: 0.7329 - val_loss: 1.0182 - val_accuracy: 0.7173
# Epoch 90/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.5949 - accuracy: 0.7325 - val_loss: 1.0175 - val_accuracy: 0.7173
# Epoch 91/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6200 - accuracy: 0.7324 - val_loss: 1.0155 - val_accuracy: 0.7173
# Epoch 92/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6209 - accuracy: 0.7337 - val_loss: 1.0148 - val_accuracy: 0.7173
# Epoch 93/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6094 - accuracy: 0.7325 - val_loss: 1.0122 - val_accuracy: 0.7174
# Epoch 94/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6003 - accuracy: 0.7325 - val_loss: 1.0134 - val_accuracy: 0.7174
# Epoch 95/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6105 - accuracy: 0.7329 - val_loss: 1.0175 - val_accuracy: 0.7174
# Epoch 96/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.5965 - accuracy: 0.7325 - val_loss: 1.0143 - val_accuracy: 0.7175
# Epoch 97/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6042 - accuracy: 0.7330 - val_loss: 1.0098 - val_accuracy: 0.7175
# Epoch 98/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6247 - accuracy: 0.7320 - val_loss: 1.0041 - val_accuracy: 0.7175
# Epoch 99/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6224 - accuracy: 0.7331 - val_loss: 0.9915 - val_accuracy: 0.7175
# Epoch 100/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6123 - accuracy: 0.7328 - val_loss: 0.9737 - val_accuracy: 0.7176

# %%
acc = []

for i in range(x_train_img.shape[0]):
  predict = model.predict([np.array([x_train_prt[i]]), np.array([x_train_img[i]])])
  
  # Accuracy
  acc.append(get_mat_accuracy(predict.reshape(448, 640), y_train[i].reshape(448, 640)))
  
  # portata, altezza media prevista
  plt.scatter(x_train_prt[i][1][1], np.mean(predict))

avg_acc = round(np.mean(acc)*100, 2)
plt.title("TRAIN Portata-Altezza media predetta (acc: {}%)".format(avg_acc))

plt.show()

# %%
plt.title("TEST Portata-Altezza media predetta")
acc = []

for i in range(x_test_img.shape[0]):
  predict = model.predict([np.array([x_test_prt[i]]), np.array([x_test_img[i]])])
  
  # Accuracy
  acc.append(get_mat_accuracy(predict.reshape(448, 640), y_test[i].reshape(448, 640)))
  
  # portata, altezza media prevista
  plt.scatter(x_test_prt[i][1][1], np.mean(predict))

avg_acc = round(np.mean(acc)*100, 2)
plt.title("TEST Portata-Altezza media predetta (acc: {}%)".format(avg_acc))

plt.show()
# Out:
# (10, 448, 640) (10, 448, 640, 1)

# %%
plt.matshow(model.predict([np.array([x_test_prt[5]]), np.array([x_test_img[5]])]).reshape(448, 640))
