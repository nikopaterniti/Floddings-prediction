# %% [markdown]
# ### Functions

# %%
import numpy as np
import pandas as pd
import os
from pathlib import Path
import tqdm
import matplotlib.pyplot as plt
import random
import torch
import torch.nn as nn
import torch.optim as optim
import seaborn as sns

# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

import keras.layers.advanced_activations as advanced_activations
import keras.activations as activations
import keras.layers as layers
from keras.layers import Dense, concatenate

# %%
import scipy.spatial.distance as distance
def plot_mat_accuracy(input, y_hat, y_true):

  input = input
  y_hat = y_hat
  y_true = y_true

  dist = distance.cosine(y_hat.flatten(), y_true.flatten())

  fig, axs = plt.subplots(1,3)
  fig.suptitle('Accuracy: {}'.format(1 - dist))
  
  axs[0].set_title("Input")
  axs[0].matshow(input)

  axs[1].set_title("Y_hat")
  axs[1].matshow(y_hat)

  axs[2].set_title("Y_true")
  axs[2].matshow(y_true)
  
  for ax in axs:
    ax.set_xticks([])
    ax.set_yticks([])

  plt.show()
      
  return 1 - dist

def get_mat_accuracy(y_hat, y_true):
  dist = distance.cosine(y_hat.flatten(), y_true.flatten())
  return 1 - dist

# %% [markdown]
# ### Data Import

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %cd drive/My\ Drive/SWE
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/My Drive/SWE

# %%
portate = np.load('datasets/numpy/portate.npy')
print(portate.shape)

binaries = np.load('datasets/numpy/binaries.npy')
print(binaries.shape)

btms = np.load('datasets/numpy/btms.npy')
print(btms.shape)
# Out:
# (100, 1, 3)
# (100, 1, 443, 640)
# (100, 1, 448, 640)

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# #### Resizing

# %%
from skimage.transform import resize

# %%
FACTOR = 0.3

binaries = np.array(
    [resize(s[0], (int(s[0].shape[0] * FACTOR), int(s[0].shape[1] * FACTOR))) for s in binaries]
)

btms = np.array(
    [resize(s[0], (int(s[0].shape[0] * FACTOR), int(s[0].shape[1] * FACTOR))) for s in btms]
)

# %%
print(binaries.shape)
print(btms.shape)
# Out:
# (100, 132, 192)
# (100, 134, 192)

# %%
plt.matshow(binaries[0])

# %% [markdown]
# #### Concatenating

# %%
model_in_shape = portate.shape[2] + (btms.shape[1] * btms.shape[2])
model_out_shape = binaries.shape[1] * binaries.shape[2]

# %%
# 100, model_in_shape (es: 300x300 + 3)
inputs = np.zeros((portate.shape[0], model_in_shape))
img_shape = model_in_shape - portate.shape[2]

for i in range(100):
  # Copia immagine flattened
  inputs[i][:img_shape] = btms[i].flatten()
  # Copia dati portata
  inputs[i][img_shape:] = portate[i][0]

# %%
TRAIN_SIZE = int(inputs.shape[0] * 0.8)

x_train, y_train = inputs[:TRAIN_SIZE], binaries[:TRAIN_SIZE]
x_test, y_test = inputs[TRAIN_SIZE:], binaries[TRAIN_SIZE:]

# %% [markdown]
# ### Feed Forward

# %%
model = Sequential(
    [
        layers.Input(model_in_shape),
        layers.BatchNormalization(),
     
        layers.Dense(128),
        layers.BatchNormalization(),
     
        layers.Dense(256),
        layers.BatchNormalization(),
     
        layers.Dense(128),
        layers.BatchNormalization(),
     
        layers.Dense(model_out_shape),
        layers.Activation(activations.sigmoid),
     
        layers.Reshape((binaries.shape[1], binaries.shape[2]))
     
    ]
)

model.compile(optimizer="Adam", loss="binary_crossentropy", metrics=["cosine_similarity"])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_16 (Batc (None, 25731)             102924
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                1646848
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 64)                256
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               8320
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 128)               512
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 64)                256
# _________________________________________________________________
# dense_19 (Dense)             (None, 25344)             1647360
# _________________________________________________________________
# activation_4 (Activation)    (None, 25344)             0
# _________________________________________________________________
# reshape_4 (Reshape)          (None, 132, 192)          0
# =================================================================
# Total params: 3,414,732
# Trainable params: 3,362,758
# Non-trainable params: 51,974
# _________________________________________________________________

# %%
epochs = 100

model.fit(
    x_train,
    y_train,
    batch_size=4,
    epochs=epochs,
    verbose=2,
    shuffle=1,
    validation_split=0.2,
)
# Out:
# Epoch 1/100
# 16/16 - 1s - loss: 0.6791 - cosine_similarity: 0.2924 - val_loss: 0.8501 - val_cosine_similarity: 0.2964
# Epoch 2/100
# 16/16 - 0s - loss: 0.6621 - cosine_similarity: 0.2973 - val_loss: 1.1291 - val_cosine_similarity: 0.2075
# Epoch 3/100
# 16/16 - 0s - loss: 0.6454 - cosine_similarity: 0.3018 - val_loss: 1.4964 - val_cosine_similarity: 0.1637
# Epoch 4/100
# 16/16 - 0s - loss: 0.6217 - cosine_similarity: 0.3095 - val_loss: 2.2763 - val_cosine_similarity: 0.1153
# Epoch 5/100
# 16/16 - 0s - loss: 0.5755 - cosine_similarity: 0.3218 - val_loss: 3.3766 - val_cosine_similarity: 0.0960
# Epoch 6/100
# 16/16 - 0s - loss: 0.5097 - cosine_similarity: 0.3397 - val_loss: 4.6736 - val_cosine_similarity: 0.0895
# Epoch 7/100
# 16/16 - 0s - loss: 0.4254 - cosine_similarity: 0.3685 - val_loss: 6.3560 - val_cosine_similarity: 0.0898
# Epoch 8/100
# 16/16 - 0s - loss: 0.3459 - cosine_similarity: 0.3964 - val_loss: 7.6632 - val_cosine_similarity: 0.0918
# Epoch 9/100
# 16/16 - 0s - loss: 0.2753 - cosine_similarity: 0.4233 - val_loss: 9.5362 - val_cosine_similarity: 0.0940
# Epoch 10/100
# 16/16 - 0s - loss: 0.2241 - cosine_similarity: 0.4440 - val_loss: 10.6425 - val_cosine_similarity: 0.0933
# Epoch 11/100
# 16/16 - 0s - loss: 0.1875 - cosine_similarity: 0.4590 - val_loss: 11.2866 - val_cosine_similarity: 0.1030
# Epoch 12/100
# 16/16 - 0s - loss: 0.1556 - cosine_similarity: 0.4717 - val_loss: 11.8358 - val_cosine_similarity: 0.1099
# Epoch 13/100
# 16/16 - 0s - loss: 0.1341 - cosine_similarity: 0.4829 - val_loss: 12.1877 - val_cosine_similarity: 0.1088
# Epoch 14/100
# 16/16 - 0s - loss: 0.1208 - cosine_similarity: 0.4939 - val_loss: 12.5232 - val_cosine_similarity: 0.1094
# Epoch 15/100
# 16/16 - 0s - loss: 0.1131 - cosine_similarity: 0.5030 - val_loss: 12.8485 - val_cosine_similarity: 0.1101
# Epoch 16/100
# 16/16 - 0s - loss: 0.0981 - cosine_similarity: 0.5154 - val_loss: 13.0417 - val_cosine_similarity: 0.1085
# Epoch 17/100
# 16/16 - 0s - loss: 0.1011 - cosine_similarity: 0.5207 - val_loss: 13.2112 - val_cosine_similarity: 0.1102
# Epoch 18/100
# 16/16 - 0s - loss: 0.0917 - cosine_similarity: 0.5318 - val_loss: 13.2695 - val_cosine_similarity: 0.1078
# Epoch 19/100
# 16/16 - 0s - loss: 0.0901 - cosine_similarity: 0.5405 - val_loss: 13.3618 - val_cosine_similarity: 0.1134
# Epoch 20/100
# 16/16 - 0s - loss: 0.0823 - cosine_similarity: 0.5498 - val_loss: 13.3949 - val_cosine_similarity: 0.1087
# Epoch 21/100
# 16/16 - 0s - loss: 0.0792 - cosine_similarity: 0.5588 - val_loss: 13.4960 - val_cosine_similarity: 0.1073
# Epoch 22/100
# 16/16 - 0s - loss: 0.0719 - cosine_similarity: 0.5693 - val_loss: 13.5758 - val_cosine_similarity: 0.1100
# Epoch 23/100
# 16/16 - 0s - loss: 0.0705 - cosine_similarity: 0.5757 - val_loss: 13.6328 - val_cosine_similarity: 0.1067
# Epoch 24/100
# 16/16 - 0s - loss: 0.0719 - cosine_similarity: 0.5805 - val_loss: 13.6899 - val_cosine_similarity: 0.1118
# Epoch 25/100
# 16/16 - 0s - loss: 0.0644 - cosine_similarity: 0.5896 - val_loss: 13.7129 - val_cosine_similarity: 0.1112
# Epoch 26/100
# 16/16 - 0s - loss: 0.0714 - cosine_similarity: 0.5889 - val_loss: 13.6180 - val_cosine_similarity: 0.0961
# Epoch 27/100
# 16/16 - 0s - loss: 0.0648 - cosine_similarity: 0.5960 - val_loss: 13.9455 - val_cosine_similarity: 0.0963
# Epoch 28/100
# 16/16 - 0s - loss: 0.0662 - cosine_similarity: 0.5985 - val_loss: 14.0043 - val_cosine_similarity: 0.1114
# Epoch 29/100
# 16/16 - 0s - loss: 0.0670 - cosine_similarity: 0.6000 - val_loss: 13.9733 - val_cosine_similarity: 0.1137
# Epoch 30/100
# 16/16 - 0s - loss: 0.0709 - cosine_similarity: 0.6020 - val_loss: 13.7589 - val_cosine_similarity: 0.1184
# Epoch 31/100
# 16/16 - 0s - loss: 0.0661 - cosine_similarity: 0.6069 - val_loss: 13.6116 - val_cosine_similarity: 0.1250
# Epoch 32/100
# 16/16 - 0s - loss: 0.0774 - cosine_similarity: 0.6050 - val_loss: 13.5237 - val_cosine_similarity: 0.1263
# Epoch 33/100
# 16/16 - 0s - loss: 0.0685 - cosine_similarity: 0.6100 - val_loss: 13.4436 - val_cosine_similarity: 0.1329
# Epoch 34/100
# 16/16 - 0s - loss: 0.0679 - cosine_similarity: 0.6121 - val_loss: 13.3755 - val_cosine_similarity: 0.1340
# Epoch 35/100
# 16/16 - 0s - loss: 0.0670 - cosine_similarity: 0.6129 - val_loss: 13.3426 - val_cosine_similarity: 0.1442
# Epoch 36/100
# 16/16 - 0s - loss: 0.0622 - cosine_similarity: 0.6163 - val_loss: 13.3475 - val_cosine_similarity: 0.1614
# Epoch 37/100
# 16/16 - 0s - loss: 0.0636 - cosine_similarity: 0.6182 - val_loss: 13.1991 - val_cosine_similarity: 0.1706
# Epoch 38/100
# 16/16 - 0s - loss: 0.0656 - cosine_similarity: 0.6198 - val_loss: 13.0726 - val_cosine_similarity: 0.1760
# Epoch 39/100
# 16/16 - 0s - loss: 0.0649 - cosine_similarity: 0.6208 - val_loss: 12.9285 - val_cosine_similarity: 0.1813
# Epoch 40/100
# 16/16 - 0s - loss: 0.0633 - cosine_similarity: 0.6225 - val_loss: 12.8601 - val_cosine_similarity: 0.1865
# Epoch 41/100
# 16/16 - 0s - loss: 0.0596 - cosine_similarity: 0.6251 - val_loss: 12.5770 - val_cosine_similarity: 0.2081
# Epoch 42/100
# 16/16 - 0s - loss: 0.0697 - cosine_similarity: 0.6224 - val_loss: 12.5514 - val_cosine_similarity: 0.2139
# Epoch 43/100
# 16/16 - 0s - loss: 0.0733 - cosine_similarity: 0.6210 - val_loss: 12.5042 - val_cosine_similarity: 0.2161
# Epoch 44/100
# 16/16 - 0s - loss: 0.0673 - cosine_similarity: 0.6221 - val_loss: 10.6204 - val_cosine_similarity: 0.2092
# Epoch 45/100
# 16/16 - 0s - loss: 0.0667 - cosine_similarity: 0.6234 - val_loss: 12.1423 - val_cosine_similarity: 0.2247
# Epoch 46/100
# 16/16 - 0s - loss: 0.0608 - cosine_similarity: 0.6280 - val_loss: 11.8455 - val_cosine_similarity: 0.2502
# Epoch 47/100
# 16/16 - 0s - loss: 0.0721 - cosine_similarity: 0.6220 - val_loss: 9.7858 - val_cosine_similarity: 0.2785
# Epoch 48/100
# 16/16 - 0s - loss: 0.0657 - cosine_similarity: 0.6269 - val_loss: 9.6979 - val_cosine_similarity: 0.2800
# Epoch 49/100
# 16/16 - 0s - loss: 0.0610 - cosine_similarity: 0.6287 - val_loss: 8.5232 - val_cosine_similarity: 0.2703
# Epoch 50/100
# 16/16 - 0s - loss: 0.0626 - cosine_similarity: 0.6284 - val_loss: 5.7229 - val_cosine_similarity: 0.2951
# Epoch 51/100
# 16/16 - 0s - loss: 0.0740 - cosine_similarity: 0.6229 - val_loss: 3.0857 - val_cosine_similarity: 0.3176
# Epoch 52/100
# 16/16 - 0s - loss: 0.0661 - cosine_similarity: 0.6298 - val_loss: 0.2373 - val_cosine_similarity: 0.5554
# Epoch 53/100
# 16/16 - 0s - loss: 0.0667 - cosine_similarity: 0.6285 - val_loss: 0.0640 - val_cosine_similarity: 0.7137
# Epoch 54/100
# 16/16 - 0s - loss: 0.0603 - cosine_similarity: 0.6339 - val_loss: 0.0694 - val_cosine_similarity: 0.7137
# Epoch 55/100
# 16/16 - 0s - loss: 0.0617 - cosine_similarity: 0.6334 - val_loss: 0.0664 - val_cosine_similarity: 0.7128
# Epoch 56/100
# 16/16 - 0s - loss: 0.0659 - cosine_similarity: 0.6338 - val_loss: 0.0671 - val_cosine_similarity: 0.7138
# Epoch 57/100
# 16/16 - 0s - loss: 0.0621 - cosine_similarity: 0.6337 - val_loss: 0.0695 - val_cosine_similarity: 0.7141
# Epoch 58/100
# 16/16 - 0s - loss: 0.0675 - cosine_similarity: 0.6315 - val_loss: 0.0576 - val_cosine_similarity: 0.7159
# Epoch 59/100
# 16/16 - 0s - loss: 0.0612 - cosine_similarity: 0.6361 - val_loss: 0.0549 - val_cosine_similarity: 0.7156
# Epoch 60/100
# 16/16 - 0s - loss: 0.0637 - cosine_similarity: 0.6354 - val_loss: 0.0746 - val_cosine_similarity: 0.7153
# Epoch 61/100
# 16/16 - 0s - loss: 0.0610 - cosine_similarity: 0.6356 - val_loss: 0.0542 - val_cosine_similarity: 0.7179
# Epoch 62/100
# 16/16 - 0s - loss: 0.0541 - cosine_similarity: 0.6412 - val_loss: 0.0615 - val_cosine_similarity: 0.7167
# Epoch 63/100
# 16/16 - 0s - loss: 0.0651 - cosine_similarity: 0.6350 - val_loss: 0.0495 - val_cosine_similarity: 0.7162
# Epoch 64/100
# 16/16 - 0s - loss: 0.0565 - cosine_similarity: 0.6414 - val_loss: 0.2761 - val_cosine_similarity: 0.5535
# Epoch 65/100
# 16/16 - 0s - loss: 0.0550 - cosine_similarity: 0.6420 - val_loss: 0.0860 - val_cosine_similarity: 0.6637
# Epoch 66/100
# 16/16 - 0s - loss: 0.0613 - cosine_similarity: 0.6396 - val_loss: 0.0866 - val_cosine_similarity: 0.6560
# Epoch 67/100
# 16/16 - 0s - loss: 0.0610 - cosine_similarity: 0.6394 - val_loss: 0.1160 - val_cosine_similarity: 0.6292
# Epoch 68/100
# 16/16 - 0s - loss: 0.0617 - cosine_similarity: 0.6405 - val_loss: 0.0555 - val_cosine_similarity: 0.7032
# Epoch 69/100
# 16/16 - 0s - loss: 0.0610 - cosine_similarity: 0.6408 - val_loss: 0.0512 - val_cosine_similarity: 0.7052
# Epoch 70/100
# 16/16 - 0s - loss: 0.0601 - cosine_similarity: 0.6420 - val_loss: 0.0495 - val_cosine_similarity: 0.7183
# Epoch 71/100
# 16/16 - 0s - loss: 0.0720 - cosine_similarity: 0.6354 - val_loss: 0.0487 - val_cosine_similarity: 0.7183
# Epoch 72/100
# 16/16 - 0s - loss: 0.0592 - cosine_similarity: 0.6411 - val_loss: 0.0511 - val_cosine_similarity: 0.7212
# Epoch 73/100
# 16/16 - 0s - loss: 0.0649 - cosine_similarity: 0.6396 - val_loss: 0.0530 - val_cosine_similarity: 0.7221
# Epoch 74/100
# 16/16 - 0s - loss: 0.0603 - cosine_similarity: 0.6423 - val_loss: 0.0538 - val_cosine_similarity: 0.7223
# Epoch 75/100
# 16/16 - 0s - loss: 0.0676 - cosine_similarity: 0.6388 - val_loss: 0.0573 - val_cosine_similarity: 0.7148
# Epoch 76/100
# 16/16 - 0s - loss: 0.0586 - cosine_similarity: 0.6423 - val_loss: 0.0597 - val_cosine_similarity: 0.7176
# Epoch 77/100
# 16/16 - 0s - loss: 0.0727 - cosine_similarity: 0.6380 - val_loss: 0.3577 - val_cosine_similarity: 0.6411
# Epoch 78/100
# 16/16 - 0s - loss: 0.0646 - cosine_similarity: 0.6393 - val_loss: 0.1856 - val_cosine_similarity: 0.6816
# Epoch 79/100
# 16/16 - 0s - loss: 0.0654 - cosine_similarity: 0.6396 - val_loss: 0.0773 - val_cosine_similarity: 0.6602
# Epoch 80/100
# 16/16 - 0s - loss: 0.0652 - cosine_similarity: 0.6386 - val_loss: 2.4580 - val_cosine_similarity: 0.3590
# Epoch 81/100
# 16/16 - 0s - loss: 0.0684 - cosine_similarity: 0.6380 - val_loss: 2.0816 - val_cosine_similarity: 0.3724
# Epoch 82/100
# 16/16 - 0s - loss: 0.0671 - cosine_similarity: 0.6382 - val_loss: 0.1341 - val_cosine_similarity: 0.6112
# Epoch 83/100
# 16/16 - 0s - loss: 0.0606 - cosine_similarity: 0.6429 - val_loss: 0.0435 - val_cosine_similarity: 0.7184
# Epoch 84/100
# 16/16 - 0s - loss: 0.0647 - cosine_similarity: 0.6420 - val_loss: 0.0447 - val_cosine_similarity: 0.7184
# Epoch 85/100
# 16/16 - 0s - loss: 0.0560 - cosine_similarity: 0.6470 - val_loss: 0.0468 - val_cosine_similarity: 0.7231
# Epoch 86/100
# 16/16 - 0s - loss: 0.0680 - cosine_similarity: 0.6418 - val_loss: 0.0476 - val_cosine_similarity: 0.7242
# Epoch 87/100
# 16/16 - 0s - loss: 0.0741 - cosine_similarity: 0.6388 - val_loss: 0.0457 - val_cosine_similarity: 0.7242
# Epoch 88/100
# 16/16 - 0s - loss: 0.0641 - cosine_similarity: 0.6430 - val_loss: 0.0476 - val_cosine_similarity: 0.7245
# Epoch 89/100
# 16/16 - 0s - loss: 0.0614 - cosine_similarity: 0.6440 - val_loss: 0.0555 - val_cosine_similarity: 0.7258
# Epoch 90/100
# 16/16 - 0s - loss: 0.0687 - cosine_similarity: 0.6418 - val_loss: 0.1162 - val_cosine_similarity: 0.7084
# Epoch 91/100
# 16/16 - 0s - loss: 0.0613 - cosine_similarity: 0.6468 - val_loss: 0.0443 - val_cosine_similarity: 0.7162
# Epoch 92/100
# 16/16 - 0s - loss: 0.0659 - cosine_similarity: 0.6426 - val_loss: 0.0513 - val_cosine_similarity: 0.6905
# Epoch 93/100
# 16/16 - 0s - loss: 0.0613 - cosine_similarity: 0.6464 - val_loss: 0.0516 - val_cosine_similarity: 0.7254
# Epoch 94/100
# 16/16 - 0s - loss: 0.0540 - cosine_similarity: 0.6503 - val_loss: 0.0563 - val_cosine_similarity: 0.7263
# Epoch 95/100
# 16/16 - 0s - loss: 0.0561 - cosine_similarity: 0.6504 - val_loss: 0.0609 - val_cosine_similarity: 0.7260
# Epoch 96/100
# 16/16 - 0s - loss: 0.0649 - cosine_similarity: 0.6461 - val_loss: 0.0552 - val_cosine_similarity: 0.7270
# Epoch 97/100
# 16/16 - 0s - loss: 0.0687 - cosine_similarity: 0.6453 - val_loss: 0.1120 - val_cosine_similarity: 0.7109
# Epoch 98/100
# 16/16 - 0s - loss: 0.0603 - cosine_similarity: 0.6476 - val_loss: 0.1895 - val_cosine_similarity: 0.6866
# Epoch 99/100
# 16/16 - 0s - loss: 0.0676 - cosine_similarity: 0.6435 - val_loss: 0.1222 - val_cosine_similarity: 0.7054
# Epoch 100/100
# 16/16 - 0s - loss: 0.0659 - cosine_similarity: 0.6449 - val_loss: 0.1107 - val_cosine_similarity: 0.7100

# %%
# btms 0 + portate 0
index = 0
res = model.predict(np.array([x_test[index]]))

# %%
# Noto che la rete ha polarizzato i valori! (YAY!)
sns.distplot(res[0].flatten())
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
THRSHLD = 0.8

res[res >= THRSHLD] = 1
res[res < THRSHLD] = 0

# %%
plot_mat_accuracy(
    x_test[index][:img_shape].reshape(btms.shape[1], btms.shape[2]),
    res[0],
    y_test[index]
)
# Out:
# 0.9640436768531799

# %%
# Test Loss
test_losses = np.zeros(x_test.shape[0])

for i, x in enumerate(x_test):
  y_hat = model.predict(np.array([x]))
  y_true = y_test[i]

  test_losses[i] = get_mat_accuracy(y_hat, y_true)

# Train loss
train_losses = np.zeros(x_train.shape[0])

for i, x in enumerate(x_train):
  y_hat = model.predict(np.array([x]))
  y_true = y_train[i]

  train_losses[i] = get_mat_accuracy(y_hat, y_true)


print("Train accuracy: {}".format(train_losses.mean()))
print("Test accuracy: {}".format(test_losses.mean()))
# Out:
# Train loss: 0.9732487395405769
# Test loss: 0.9602359175682068

# %% [markdown]
# #### Considerazioni
# - L'attivazione ReLU "taglia" dei valori intermedi, la rete impara di conseguenza a prevedere SOLO la matrice binaria finale per tutti gli step
# - La BatchNormalization() ad ogni livello migliora le prestazioni
# - La sigmoid ad ogni livello migliora le prestazioni
# - I valori predetti sono polarizzati tra 0 e 1, ho applicato una trasformazione in post per convertirli in binario
# - Con troppi neuroni il modello pensa ci siano piú celle allagate del previsto
# - Inaspettatamente, con molti meno neuroni la rete lavora meglio. Dimostra che non c'é una relazione lineare tra la dimensione input e la dimensione della rete
# - Valutare ACCURACY e provare ad applicare un layer custom che approssimi i valori binari
#
# #### Grid search
# - Caso 1
#   - layers: 2048-4096-2048
#   - Train loss: 0.9599439859390259
#   - Test loss: 0.7443766593933105
# - Caso 2
#   - layers: 1024-2048-1024
#   - Train loss: 0.9633248627185822
#   - Test loss: 0.9483283877372741
# - Caso 3
#   - layers: 1024-1024-1024
#   - Train loss: 0.9602072075009346
#   - Test loss: 0.7796615689992905
# - Caso 4
#   - layers: 256-512-256
#   - Train loss: 0.9725818052887917
#   - Test loss: 0.972408851981163
# - Caso 5
#   - layers: 128-256-128
#   - Train loss: 0.9711698390543461
#   - Test loss: 0.9726134836673737
# - Caso 6
#   - layers: 64-128-64
#   - Train loss: 0.9732487395405769
#   - Test loss: 0.9602359175682068
